# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import json
import time
import math
import itertools
pd.set_option('display.max_columns', None)

# %%
df18= pd.read_csv(r'C:\Users\gmart\Desktop\EPFL 2° SEMESTRE\DATA SCIENCE\Data-Science-in-Practice\Project\2018weekconcat.csv')
df19= pd.read_csv(r'C:\Users\gmart\Desktop\EPFL 2° SEMESTRE\DATA SCIENCE\Data-Science-in-Practice\Project\2019weekconcat.csv')
df19_merge = df19.copy()
df19_merge.week = df19_merge.week + df18.week.max()
dfall=pd.concat([df18, df19_merge], ignore_index=True)

# %%
print(dfall.shape)
print(dfall.dtypes)
dfall.head()
# Out:
# (20800, 25)
# Position              int64
# Track Name           object
# Artist               object
# Streams               int64
# URL                  object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# week                  int64
# year                  int64
# dtype: object
#    Position                       Track Name       Artist  Streams  \
# 0         1                         rockstar  Post Malone  9855305
# 1         2   Finesse - Remix; feat. Cardi B   Bruno Mars  8504248
# 2         3                         No Limit       G-Eazy  7685058
# 3         4  Bartier Cardi (feat. 21 Savage)      Cardi B  7439471
# 4         5                     I Fall Apart  Post Malone  6971450
#
#                                                  URL  danceability  energy  \
# 0  https://open.spotify.com/track/7wGoVu4Dady5GV0...         0.577   0.522
# 1  https://open.spotify.com/track/3Vo4wInECJQuz9B...         0.704   0.859
# 2  https://open.spotify.com/track/2DQ1ITjI0YoLFzu...         0.838   0.771
# 3  https://open.spotify.com/track/75FDPwaULRdYDn4...         0.909   0.546
# 4  https://open.spotify.com/track/75ZvA4QfFiZvzhj...         0.556   0.538
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    5    -6.594     0       0.0984      0.130000          0.000090    0.1420
# 1    5    -4.877     0       0.0996      0.018500          0.000000    0.0215
# 2    1    -3.791     1       0.2440      0.011700          0.000000    0.0853
# 3    8    -7.513     1       0.1750      0.000704          0.000823    0.3600
# 4    8    -5.408     0       0.0382      0.068900          0.000000    0.1960
#
#    valence    tempo            type                      id  \
# 0   0.1190  159.772  audio_features  7wGoVu4Dady5GV0Sv4UIsx
# 1   0.9260  105.115  audio_features  3Vo4wInECJQuz9BIBMOu8i
# 2   0.4050  175.957  audio_features  2DQ1ITjI0YoLFzuADN1ZBW
# 3   0.0986  138.043  audio_features  75FDPwaULRdYDn4StFN2rT
# 4   0.2910  143.950  audio_features  75ZvA4QfFiZvzhj2xkaWAh
#
#                                     uri  \
# 0  spotify:track:7wGoVu4Dady5GV0Sv4UIsx
# 1  spotify:track:3Vo4wInECJQuz9BIBMOu8i
# 2  spotify:track:2DQ1ITjI0YoLFzuADN1ZBW
# 3  spotify:track:75FDPwaULRdYDn4StFN2rT
# 4  spotify:track:75ZvA4QfFiZvzhj2xkaWAh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7wGoVu4Dady5...
# 1  https://api.spotify.com/v1/tracks/3Vo4wInECJQu...
# 2  https://api.spotify.com/v1/tracks/2DQ1ITjI0YoL...
# 3  https://api.spotify.com/v1/tracks/75FDPwaULRdY...
# 4  https://api.spotify.com/v1/tracks/75ZvA4QfFiZv...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7wGo...       218320
# 1  https://api.spotify.com/v1/audio-analysis/3Vo4...       217289
# 2  https://api.spotify.com/v1/audio-analysis/2DQ1...       245387
# 3  https://api.spotify.com/v1/audio-analysis/75FD...       224613
# 4  https://api.spotify.com/v1/audio-analysis/75Zv...       223347
#
#    time_signature  week  year
# 0               4     1  2018
# 1               4     1  2018
# 2               4     1  2018
# 3               4     1  2018
# 4               4     1  2018

# %%
dfall.describe(include=['O'])
# Out:
#           Track Name       Artist  \
# count          20800        20800
# unique          2177          462
# top     I Fall Apart  Post Malone
# freq             104         1108
#
#                                                       URL            type  \
# count                                               20800           20800
# unique                                               2601               1
# top     https://open.spotify.com/track/75ZvA4QfFiZvzhj...  audio_features
# freq                                                  104           20800
#
#                             id                                   uri  \
# count                    20800                                 20800
# unique                    2601                                  2601
# top     7m9OqQk4RVRkw9JJdeAw96  spotify:track:75ZvA4QfFiZvzhj2xkaWAh
# freq                       104                                   104
#
#                                                track_href  \
# count                                               20800
# unique                                               2601
# top     https://api.spotify.com/v1/tracks/75ZvA4QfFiZv...
# freq                                                  104
#
#                                              analysis_url
# count                                               20800
# unique                                               2601
# top     https://api.spotify.com/v1/audio-analysis/75Zv...
# freq                                                  104

# %%
dfall.describe()
# Out:
#            Position       Streams  danceability        energy           key  \
# count  20800.000000  2.080000e+04  20800.000000  20800.000000  20800.000000
# mean     100.500000  2.940632e+06      0.710261      0.602620      5.381827
# std       57.735693  2.076036e+06      0.140196      0.153113      3.694429
# min        1.000000  1.253378e+06      0.153000      0.005430      0.000000
# 25%       50.750000  1.747271e+06      0.622000      0.515000      1.000000
# 50%      100.500000  2.210628e+06      0.729000      0.604000      6.000000
# 75%      150.250000  3.278719e+06      0.809000      0.716000      9.000000
# max      200.000000  3.074768e+07      0.980000      0.958000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  20800.000000  20800.000000  20800.000000  20800.000000
# mean      -6.564735      0.596923      0.141134      0.228278
# std        2.415184      0.490528      0.121337      0.239117
# min      -25.166000      0.000000      0.023200      0.000031
# 25%       -7.681000      0.000000      0.047600      0.042100
# 50%       -6.274000      1.000000      0.090500      0.140000
# 75%       -5.024000      1.000000      0.212000      0.334000
# max        0.175000      1.000000      0.966000      0.994000
#
#        instrumentalness      liveness       valence         tempo  \
# count      20800.000000  20800.000000  20800.000000  20800.000000
# mean           0.007029      0.165903      0.450066    122.506819
# std            0.049629      0.117985      0.202074     29.765913
# min            0.000000      0.021500      0.036100     46.718000
# 25%            0.000000      0.099000      0.294750     97.092000
# 50%            0.000000      0.119000      0.435000    123.911000
# 75%            0.000007      0.190000      0.588000    144.111000
# max            0.942000      0.914000      0.982000    207.476000
#
#          duration_ms  time_signature          week          year
# count   20800.000000    20800.000000  20800.000000  20800.000000
# mean   199708.251394        3.977981     52.500000   2018.500000
# std     44385.318150        0.263846     30.021548      0.500012
# min     31200.000000        1.000000      1.000000   2018.000000
# 25%    173926.000000        4.000000     26.750000   2018.000000
# 50%    197957.500000        4.000000     52.500000   2018.500000
# 75%    221440.000000        4.000000     78.250000   2019.000000
# max    943529.000000        5.000000    104.000000   2019.000000

# %%
def histogram(feature):
    plt.figure(figsize=(10, 5))
    plt.title("Histogram for {}".format(feature))
    ax = sns.distplot(dfall[feature],color=sns.color_palette("Pastel2")[0])
histogram('Streams')
histogram('danceability')
histogram('energy')
histogram('loudness')
histogram('speechiness')
histogram('acousticness')
histogram('instrumentalness')
histogram('liveness')
histogram('valence')
histogram('tempo')
histogram('duration_ms')

# %%
dfall.boxplot(return_type="dict")
plt.plot()
# Out:
# []

# %%
sns.boxplot(dfall["energy"])

# %%
sns.boxplot(dfall["loudness"])

# %%
   sns.boxplot(dfall["liveness"])

# %%
      sns.boxplot(dfall["acousticness"])

# %%
 sns.boxplot(dfall["speechiness"])

# %%
   sns.boxplot(dfall["duration_ms"])

# %%
 sns.boxplot(dfall["tempo"])

# %%
sns.boxplot(dfall["Streams"])

# %%
   sns.boxplot(dfall["valence"])

# %%
sns.boxplot(dfall["danceability"])

# %% [markdown]
# # OUTLIERS

# %% [markdown]
# https://www.youtube.com/watch?v=rzR_cKnkD18

# %%
outliers=[] 
def detect_outliers(dfall):

    threshold=3
    mean=np.mean(dfall)
    std=np.std(dfall)
    
    for i in dfall:
    z_score= (i - mean)/std
    if np.abs(z_score) > threshold:
        outliers.append(y)
        return outliers
# Out:
#   File "<ipython-input-21-9e00981d4611>", line 1
#     outliers=[] %https://www.youtube.com/watch?v=rzR_cKnkD18
#                       ^
# SyntaxError: invalid syntax

# %%
outlier_pt=detect_outliers(dfall)

# %%
mid= np.median(outlier_pt)

# %%
lower_bound=0.1
upper_bound=0.95
res=dfall.quantile([lower_bound, upper_bound])
res
# Out:
#       Position    Streams  danceability  energy   key  loudness  mode  \
# 0.10     20.90  1556392.0         0.516   0.400   1.0    -9.441   0.0
# 0.95    190.05  6908216.5         0.917   0.841  11.0    -3.240   1.0
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# 0.10       0.0351         0.013          0.000000    0.0813    0.186
# 0.95       0.3950         0.751          0.008542    0.3950    0.814
#
#           tempo  duration_ms  time_signature  week    year
# 0.10   83.90300     146520.0             4.0  11.0  2018.0
# 0.95  171.94665     272307.0             4.0  99.0  2019.0

# %%
true_index=(res.loc[lower_bound]<dfall) & (dfall<res.loc[upper_bound])
true_index
# Out:
#        Artist  Position  Streams  Track Name    URL  acousticness  \
# 0       False     False    False       False  False          True
# 1       False     False    False       False  False          True
# 2       False     False    False       False  False         False
# 3       False     False    False       False  False         False
# 4       False     False    False       False  False          True
# ...       ...       ...      ...         ...    ...           ...
# 20795   False     False    False       False  False          True
# 20796   False     False    False       False  False          True
# 20797   False     False    False       False  False          True
# 20798   False     False    False       False  False         False
# 20799   False     False    False       False  False          True
#
#        analysis_url  danceability  duration_ms  energy     id  \
# 0             False          True         True    True  False
# 1             False          True         True   False  False
# 2             False          True         True    True  False
# 3             False          True         True    True  False
# 4             False          True         True    True  False
# ...             ...           ...          ...     ...    ...
# 20795         False          True         True    True  False
# 20796         False          True         True    True  False
# 20797         False         False         True    True  False
# 20798         False          True         True   False  False
# 20799         False          True         True    True  False
#
#        instrumentalness    key  liveness  loudness   mode  speechiness  tempo  \
# 0                  True   True      True      True  False         True   True
# 1                 False   True     False      True  False         True   True
# 2                 False  False      True      True  False         True  False
# 3                  True   True      True      True  False         True   True
# 4                 False   True      True      True  False         True   True
# ...                 ...    ...       ...       ...    ...          ...    ...
# 20795             False   True      True      True  False         True   True
# 20796              True  False      True      True  False         True   True
# 20797             False   True      True     False  False         True   True
# 20798             False   True     False     False  False         True   True
# 20799             False   True      True      True  False         True   True
#
#        time_signature  track_href   type    uri  valence   week   year
# 0               False       False  False  False    False  False  False
# 1               False       False  False  False    False  False  False
# 2               False       False  False  False     True  False  False
# 3               False       False  False  False    False  False  False
# 4               False       False  False  False     True  False  False
# ...               ...         ...    ...    ...      ...    ...    ...
# 20795           False       False  False  False     True  False  False
# 20796           False       False  False  False     True  False  False
# 20797           False       False  False  False    False  False  False
# 20798           False       False  False  False    False  False  False
# 20799           False       False  False  False     True  False  False
#
# [20800 rows x 25 columns]

# %%
false_index=-true_index
false_index
# Out:
#        Artist  Position  Streams  Track Name   URL  acousticness  \
# 0        True      True     True        True  True         False
# 1        True      True     True        True  True         False
# 2        True      True     True        True  True          True
# 3        True      True     True        True  True          True
# 4        True      True     True        True  True         False
# ...       ...       ...      ...         ...   ...           ...
# 20795    True      True     True        True  True         False
# 20796    True      True     True        True  True         False
# 20797    True      True     True        True  True         False
# 20798    True      True     True        True  True          True
# 20799    True      True     True        True  True         False
#
#        analysis_url  danceability  duration_ms  energy    id  \
# 0              True         False        False   False  True
# 1              True         False        False    True  True
# 2              True         False        False   False  True
# 3              True         False        False   False  True
# 4              True         False        False   False  True
# ...             ...           ...          ...     ...   ...
# 20795          True         False        False   False  True
# 20796          True         False        False   False  True
# 20797          True          True        False   False  True
# 20798          True         False        False    True  True
# 20799          True         False        False   False  True
#
#        instrumentalness    key  liveness  loudness  mode  speechiness  tempo  \
# 0                 False  False     False     False  True        False  False
# 1                  True  False      True     False  True        False  False
# 2                  True   True     False     False  True        False   True
# 3                 False  False     False     False  True        False  False
# 4                  True  False     False     False  True        False  False
# ...                 ...    ...       ...       ...   ...          ...    ...
# 20795              True  False     False     False  True        False  False
# 20796             False   True     False     False  True        False  False
# 20797              True  False     False      True  True        False  False
# 20798              True  False      True      True  True        False  False
# 20799              True  False     False     False  True        False  False
#
#        time_signature  track_href  type   uri  valence  week  year
# 0                True        True  True  True     True  True  True
# 1                True        True  True  True     True  True  True
# 2                True        True  True  True    False  True  True
# 3                True        True  True  True     True  True  True
# 4                True        True  True  True    False  True  True
# ...               ...         ...   ...   ...      ...   ...   ...
# 20795            True        True  True  True    False  True  True
# 20796            True        True  True  True    False  True  True
# 20797            True        True  True  True     True  True  True
# 20798            True        True  True  True     True  True  True
# 20799            True        True  True  True    False  True  True
#
# [20800 rows x 25 columns]

# %%
mid= np.median(dfall[true_index])
mid
# Out:
# nan

# %%
dfall[false_index]=mid

# %%
continuous_cols = [
    'energy',
    'danceability',
    'loudness',
    'liveness',
    'valence',
    'acousticness',
    'speechiness',
    'duration_ms',
    'instrumentalness',
    'tempo',
    'Streams'
    
]
f, ax = plt.subplots(figsize=[9,6])
ax = sns.heatmap(dfall[continuous_cols].corr(), 
                 annot=True, fmt=".2f",
                 vmin=-1, vmax=1,
                 cbar_kws={'label': 'Correlation Coefficient'})
ax.set_title("Continuous Variable Correlation Matrix")
plt.show()

# %%
for column in dfall.columns:
        if dfall[column].dtype=="O":
            print(column,dfall[column].unique())
# Out:
# Track Name [nan]
# Artist [nan]
# URL [nan]
# type [nan]
# id [nan]
# uri [nan]
# track_href [nan]
# analysis_url [nan]

# %%
plt.figure(figsize=(12, 6))
corr = dfall.apply(lambda x: pd.factorize(x)[0]).corr()
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
                 linewidths=.2, cmap="YlGnBu")

# %%
dummies=pd.get_dummies(dfall["URL"],prefix="URL")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="URL")

dummies=pd.get_dummies(dfall["Artist"],prefix="Artist")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="Artist")


dummies=pd.get_dummies(dfall["key"],prefix="key")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="key")

dummies=pd.get_dummies(dfall["mode"],prefix="mode")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="mode")


dummies=pd.get_dummies(dfall["type"],prefix="type")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="type")

dummies=pd.get_dummies(dfall["id"],prefix="id")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="id")

dummies=pd.get_dummies(dfall["uri"],prefix="uri")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="uri")

dummies=pd.get_dummies(dfall["track_href"],prefix="track_href")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="track_href")

dummies=pd.get_dummies(dfall["analysis_url"],prefix="analysis_url")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="analysis_url")

dummies=pd.get_dummies(dfall["Track Name"],prefix="Track Name")
dfall = pd.concat([dfall, dummies], axis=1)
dfall=dfall.drop(columns="Track Name")

# %%
plt.figure(figsize=(12, 6))
corr = dfall.apply(lambda x: pd.factorize(x)[0]).corr()
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
                 linewidths=.2, cmap="YlGnBu")
